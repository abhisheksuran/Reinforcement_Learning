# %% [markdown]
# <a href="https://colab.research.google.com/github/abhisheksuran/Atari_DQN/blob/master/DDDQN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf 
import numpy as np 
import gym
from tensorflow.keras.models import load_model

# %%
# !pip3 install box2d-py
# Out:
# Collecting box2d-py
#   Downloading https://files.pythonhosted.org/packages/06/bd/6cdc3fd994b0649dcf5d9bad85bd9e26172308bbe9a421bfc6fdbf5081a6/box2d_py-2.3.8-cp36-cp36m-manylinux1_x86_64.whl (448kB)
#      |████████████████████████████████| 450kB 3.4MB/s
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8

# %%
env= gym.make("LunarLander-v2")
low = env.observation_space.low
high = env.observation_space.high

# %%
class DDDQN(tf.keras.Model):
    def __init__(self):
      super(DDDQN, self).__init__()
      self.d1 = tf.keras.layers.Dense(128, activation='relu')
      self.d2 = tf.keras.layers.Dense(128, activation='relu')
      self.v = tf.keras.layers.Dense(1, activation=None)
      self.a = tf.keras.layers.Dense(env.action_space.n, activation=None)

    def call(self, input_data):
      x = self.d1(input_data)
      x = self.d2(x)
      v = self.v(x)
      a = self.a(x)
      Q = v +(a -tf.math.reduce_mean(a, axis=1, keepdims=True))
      return Q

    def advantage(self, state):
      x = self.d1(state)
      x = self.d2(x)
      a = self.a(x)
      return a

# %%
class exp_replay():
    def __init__(self, buffer_size= 1000000):
        self.buffer_size = buffer_size
        self.state_mem = np.zeros((self.buffer_size, *(env.observation_space.shape)), dtype=np.float32)
        self.action_mem = np.zeros((self.buffer_size), dtype=np.int32)
        self.reward_mem = np.zeros((self.buffer_size), dtype=np.float32)
        self.next_state_mem = np.zeros((self.buffer_size, *(env.observation_space.shape)), dtype=np.float32)
        self.done_mem = np.zeros((self.buffer_size), dtype=np.bool)
        self.pointer = 0

    def add_exp(self, state, action, reward, next_state, done):
        idx  = self.pointer % self.buffer_size 
        self.state_mem[idx] = state
        self.action_mem[idx] = action
        self.reward_mem[idx] = reward
        self.next_state_mem[idx] = next_state
        self.done_mem[idx] = 1 - int(done)
        self.pointer += 1

    def sample_exp(self, batch_size= 64):
        max_mem = min(self.pointer, self.buffer_size)
        batch = np.random.choice(max_mem, batch_size, replace=False)
        states = self.state_mem[batch]
        actions = self.action_mem[batch]
        rewards = self.reward_mem[batch]
        next_states = self.next_state_mem[batch]
        dones = self.done_mem[batch]
        return states, actions, rewards, next_states, dones

# %%
class agent():
      def __init__(self, gamma=0.99, replace=100, lr=0.001):
          self.gamma = gamma
          self.epsilon = 1.0
          self.min_epsilon = 0.01
          self.epsilon_decay = 1e-3
          self.replace = replace
          self.trainstep = 0
          self.memory = exp_replay()
          self.batch_size = 64
          self.q_net = DDDQN()
          self.target_net = DDDQN()
          opt = tf.keras.optimizers.Adam(learning_rate=lr)
          self.q_net.compile(loss='mse', optimizer=opt)
          self.target_net.compile(loss='mse', optimizer=opt)


      def act(self, state):
          if np.random.rand() <= self.epsilon:
              return np.random.choice([i for i in range(env.action_space.n)])

          else:
              actions = self.q_net.advantage(np.array([state]))
              action = np.argmax(actions)
              return action


      
      def update_mem(self, state, action, reward, next_state, done):
          self.memory.add_exp(state, action, reward, next_state, done)


      def update_target(self):
          self.target_net.set_weights(self.q_net.get_weights())     

      def update_epsilon(self):
          self.epsilon = self.epsilon - self.epsilon_decay if self.epsilon > self.min_epsilon else self.min_epsilon
          return self.epsilon

          
      def train(self):
          if self.memory.pointer < self.batch_size:
             return 
          
          if self.trainstep % self.replace == 0:
             self.update_target()
          states, actions, rewards, next_states, dones = self.memory.sample_exp(self.batch_size)
          target = self.q_net.predict(states)
          next_state_val = self.target_net.predict(next_states)
          max_action = np.argmax(self.q_net.predict(next_states), axis=1)
          batch_index = np.arange(self.batch_size, dtype=np.int32)
          q_target = np.copy(target)
          q_target[batch_index, actions] = rewards + self.gamma * next_state_val[batch_index, max_action]*dones
          self.q_net.train_on_batch(states, q_target)
          self.update_epsilon()
          self.trainstep += 1

      def save_model(self):
          self.q_net.save("model.h5")
          self.target_net.save("target_model.h5")


      def load_model(self):
          self.q_net = load_model("model.h5")
          self.target_net = load_model("model.h5")

# %%
agentoo7 = agent()
steps = 400
for s in range(steps):
  done = False
  state = env.reset()
  total_reward = 0
  while not done:
    #env.render()
    action = agentoo7.act(state)
    next_state, reward, done, _ = env.step(action)
    agentoo7.update_mem(state, action, reward, next_state, done)
    agentoo7.train()
    state = next_state
    total_reward += reward
    
    if done:
      print("total reward after {} episode is {} and epsilon is {}".format(s, total_reward, agentoo7.epsilon))
# Out:
# total reward after 0 episode is -111.92346954157561 and epsilon is 0.991
# total reward after 1 episode is -271.61288142788675 and epsilon is 0.8969999999999999
# total reward after 2 episode is -85.82763318050152 and epsilon is 0.8329999999999999
# total reward after 3 episode is -161.77385305579173 and epsilon is 0.7649999999999998
# total reward after 4 episode is -26.19204501091575 and epsilon is 0.6829999999999997
# total reward after 5 episode is -456.2594406780948 and epsilon is 0.5529999999999996
# total reward after 6 episode is -285.42813478035725 and epsilon is 0.3059999999999994
# total reward after 7 episode is -270.03981550295214 and epsilon is 0.14299999999999924
# total reward after 8 episode is -120.946282864365 and epsilon is 0.01
# total reward after 9 episode is -118.83585612843262 and epsilon is 0.01
# total reward after 10 episode is -45.4930394307914 and epsilon is 0.01
# total reward after 11 episode is -176.72384024412753 and epsilon is 0.01
# total reward after 12 episode is -31.045046650478255 and epsilon is 0.01
# total reward after 13 episode is -181.353222061011 and epsilon is 0.01
# total reward after 14 episode is 14.778113005943169 and epsilon is 0.01
# total reward after 15 episode is -189.0201505554512 and epsilon is 0.01
# total reward after 16 episode is -205.92533766796655 and epsilon is 0.01
# total reward after 17 episode is -197.38184049776066 and epsilon is 0.01
# total reward after 18 episode is -223.39179216420303 and epsilon is 0.01
# total reward after 19 episode is -88.69007752140186 and epsilon is 0.01
# total reward after 20 episode is -161.71877434594975 and epsilon is 0.01
# total reward after 21 episode is -99.8221726485228 and epsilon is 0.01
# total reward after 22 episode is -63.26659182966111 and epsilon is 0.01
# total reward after 23 episode is -55.734308740993995 and epsilon is 0.01
# total reward after 24 episode is -5.632937618631004 and epsilon is 0.01
# total reward after 25 episode is -62.406972449777065 and epsilon is 0.01
# total reward after 26 episode is -66.83624340197886 and epsilon is 0.01
# total reward after 27 episode is -28.62908348025839 and epsilon is 0.01
# total reward after 28 episode is -40.84292313368244 and epsilon is 0.01
# total reward after 29 episode is -38.72467522380733 and epsilon is 0.01
# total reward after 30 episode is -19.67661954638519 and epsilon is 0.01
# total reward after 31 episode is -24.95393420882097 and epsilon is 0.01
# total reward after 32 episode is -74.61761302047958 and epsilon is 0.01
# total reward after 33 episode is -30.26377706442065 and epsilon is 0.01
# total reward after 34 episode is -65.86982185428516 and epsilon is 0.01
# total reward after 35 episode is 2.097582436652899 and epsilon is 0.01
# total reward after 36 episode is -37.74021789248513 and epsilon is 0.01
# total reward after 37 episode is -3.6861966994459365 and epsilon is 0.01
# total reward after 38 episode is -145.1322171040582 and epsilon is 0.01
# total reward after 39 episode is -37.99117284607571 and epsilon is 0.01
# total reward after 40 episode is -57.674778989923716 and epsilon is 0.01
# total reward after 41 episode is -26.947365698705795 and epsilon is 0.01
# total reward after 42 episode is -49.77640733031722 and epsilon is 0.01
# total reward after 43 episode is -73.86729580579816 and epsilon is 0.01
# total reward after 44 episode is -73.83456261442429 and epsilon is 0.01
# total reward after 45 episode is -16.13258469864798 and epsilon is 0.01
# total reward after 46 episode is -47.08431673763023 and epsilon is 0.01
# total reward after 47 episode is -48.38067136568372 and epsilon is 0.01
# total reward after 48 episode is -69.10850785750844 and epsilon is 0.01
# total reward after 49 episode is -12.11040487934045 and epsilon is 0.01
# total reward after 50 episode is -16.38838849908646 and epsilon is 0.01
# total reward after 51 episode is -27.7964597701188 and epsilon is 0.01
# total reward after 52 episode is -42.92745561918538 and epsilon is 0.01
# total reward after 53 episode is -66.62608304924922 and epsilon is 0.01
# total reward after 54 episode is -40.16804455775175 and epsilon is 0.01
# total reward after 55 episode is -71.46912786764032 and epsilon is 0.01
# total reward after 56 episode is -42.50619528723839 and epsilon is 0.01
# total reward after 57 episode is -28.547631915973124 and epsilon is 0.01
# total reward after 58 episode is -119.32394668733008 and epsilon is 0.01
# total reward after 59 episode is -40.70456528751408 and epsilon is 0.01
# total reward after 60 episode is -112.01114952076817 and epsilon is 0.01
# total reward after 61 episode is -43.26443019148245 and epsilon is 0.01
# total reward after 62 episode is -50.50539419627601 and epsilon is 0.01
# total reward after 63 episode is -8.259348036918492 and epsilon is 0.01
# total reward after 64 episode is -6.913977205481696 and epsilon is 0.01
# total reward after 65 episode is -19.762148024874506 and epsilon is 0.01
# total reward after 66 episode is -104.1762300666935 and epsilon is 0.01
# total reward after 67 episode is -48.20304056612667 and epsilon is 0.01
# total reward after 68 episode is -46.11976690757175 and epsilon is 0.01
# total reward after 69 episode is -128.23972544645318 and epsilon is 0.01
# total reward after 70 episode is -28.209587579716594 and epsilon is 0.01
# total reward after 71 episode is -22.89816057976357 and epsilon is 0.01
# total reward after 72 episode is -25.657186538159532 and epsilon is 0.01
# total reward after 73 episode is -43.37802862557405 and epsilon is 0.01
# total reward after 74 episode is -4.878428645249424 and epsilon is 0.01
# total reward after 75 episode is -42.86420875502213 and epsilon is 0.01
